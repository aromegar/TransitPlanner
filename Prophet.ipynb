# %% [markdown]
# # Prophet

# %%
import pandas as pd

# %%
df = pd.read_excel("DATA/evol_pobl.xls")

# %%
df.columns = ["Año","Municipio","Provincia","Mun/Prov"]
df = df.drop(range(35,39))
df = df.drop(range(0,4))
df = df.reset_index(drop=True)
df["Año"] = df.Año.apply(lambda x : str(x)[0:4])

# %%
df
# Out:
#      Año Municipio Provincia  Mun/Prov
# 0   1900    147271    552455  0.266576
# 1   1910    153258    591210  0.259228
# 2   1920    205723    704344  0.292077
# 3   1930    217788    792308  0.274878
# 4   1940    302300    957362  0.315764
# 5   1950    374138   1101595  0.339633
# 6   1960    441869   1244153  0.355156
# 7   1970    545692   1336669  0.408248
# 8   1975    589721   1378543  0.427786
# 9   1981    645817   1478311  0.436861
# 10  1986    651084   1540907  0.422533
# 11  1991    683028   1619703    0.4217
# 12  2001    702520   1747441  0.402028
# 13  2002    704114   1758720  0.400356
# 14  2003    709975   1782862  0.398222
# 15  2004    704203   1792420  0.392878
# 16  2005    704154   1813908  0.388197
# 17  2006    704414   1835077  0.383861
# 18  2007    699145   1849268  0.378066
# 19  2008    699759   1875462  0.373113
# 20  2009    703206   1900224  0.370065
# 21  2010    704198   1917097  0.367325
# 22  2011    703021   1928962  0.364456
# 23  2012    702355   1938974   0.36223
# 24  2013    700169   1942155  0.360511
# 25  2014    696676   1941355  0.358861
# 26  2015    693878   1941480  0.357396
# 27  2016    690566   1939775  0.356003
# 28  2017    689434   1939527  0.355465
# 29  2018    688711   1939887  0.355026
# 30  2019    688592   1942389  0.354508

# %%
import seaborn as sns

# %%
sns.lineplot(data=df, x="Año", y="Municipio")
# Out:
# <AxesSubplot:xlabel='Año', ylabel='Municipio'>

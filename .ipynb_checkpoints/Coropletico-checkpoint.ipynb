# %%
import json
import folium
import pandas as pd

# %%
barrios = r"DATA/barrios.geojson"
with open (barrios) as geo_file:
    geo_json_data = json.load(geo_file)

# %%
mapa = folium.Map([40.4216,-3.6780], zoom_start=12, tiles="cartodbpositron");
folium.GeoJson(geo_json_data).add_to(mapa);

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
geo_json_data.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
geo_json_data["features"][0]["properties"]["codbar"]
# Out:
# '163'

# %%
geo_json_data["features"][0]["properties"]["nombre"]
# Out:
# 'Canillas'

# %%
geo_json_data["features"][25]["properties"]
# Out:
# {'nomdis': 'Salamanca',
#  'codbar': '041',
#  'coddistrit': '04',
#  'codbarrio': '4-1',
#  'nombre': 'Recoletos',
#  'shape_area': 870858.012835,
#  'shape_len': 3927.06892358,
#  'cartodb_id': 20,
#  'created_at': '2015-04-22T00:00:00Z',
#  'updated_at': '2015-04-22T00:00:00Z'}

# %%
len(geo_json_data["features"])
# Out:
# 128

# %%
codname=[]
for elem in geo_json_data["features"]:
    codname.append(elem["properties"]["codbar"])

# %%
type(codname)
# Out:
# list

# %%
codigos=sorted(codname)

# %%
codigos
# Out:
# ['011',
#  '012',
#  '013',
#  '014',
#  '015',
#  '016',
#  '021',
#  '022',
#  '023',
#  '024',
#  '025',
#  '026',
#  '027',
#  '031',
#  '032',
#  '033',
#  '034',
#  '035',
#  '036',
#  '041',
#  '042',
#  '043',
#  '044',
#  '045',
#  '046',
#  '051',
#  '052',
#  '053',
#  '054',
#  '055',
#  '056',
#  '061',
#  '062',
#  '063',
#  '064',
#  '065',
#  '066',
#  '071',
#  '072',
#  '073',
#  '074',
#  '075',
#  '076',
#  '081',
#  '082',
#  '083',
#  '084',
#  '085',
#  '086',
#  '087',
#  '088',
#  '091',
#  '092',
#  '093',
#  '094',
#  '095',
#  '096',
#  '097',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '131',
#  '132',
#  '133',
#  '134',
#  '135',
#  '136',
#  '141',
#  '142',
#  '143',
#  '144',
#  '145',
#  '146',
#  '151',
#  '152',
#  '153',
#  '154',
#  '155',
#  '156',
#  '157',
#  '158',
#  '159',
# ...

# %%
df = pd.read_csv("DATA/barrios_pobl.csv")
df["código"]=c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-0491a962f404> in <module>
#       1 df = pd.read_csv("DATA/barrios_pobl.csv")
# ----> 2 df["código"]=codigos
#
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# ...

# %%
df.shape
# Out:
# (131, 3)

# %%
state_data = pd.read_csv(US_Unemployment_Oct2012)

m = folium.Map(location=[48, -102], zoom_start=3)
folium.Choropleth(
    geo_data=us_states,
    data=state_data,
    columns=["State", "Unemployment"],
    key_on="feature.id",
    fill_color="YlGn",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Unemployment Rate (%)",
    highlight=True,
).add_to(m)

m
